# %% [markdown]
# <a href="https://colab.research.google.com/github/lucasjustel30/Benchmark_xlsx.py/blob/main/Base100.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
doc = pd.read_excel('benchmark.xlsx', sheet_name='PETR4')
plt.plot(doc['x'], doc['z'], color='red')

doc = pd.read_excel('benchmark.xlsx', sheet_name='BOVA11') 
plt.plot(doc['x'], doc['z'], color='blue')


plt.title('PETR4 X BOVA11', size='20', color='black')
plt.legend(['PETR4','BOVA11'], loc = 'upper left')
plt.axis((0,30,85,115))
plt.xlabel('Setembro', size='15')
plt.ylabel('Variação',size='15')
plt.grid()

# %%
doc = pd.read_excel('benchmark1.xlsx', sheet_name='PETR4')
plt.plot(doc['x'], doc['z'], color='red')

doc = pd.read_excel('benchmark1.xlsx', sheet_name='BOVA11') 
plt.plot(doc['x'], doc['z'], color='blue')

plt.title('PETR4 X BOVA11', size='20', color='black')
plt.legend(['PETR4','BOVA11'], loc = 'lower right')
plt.xlabel('2021', size='15')
plt.ylabel('Variação',size='15')
plt.ylim(70,115)
plt.grid()
